# %%
! pip install https://ray-ci-artifact-pr-public.s3.amazonaws.com/7d65ae53c243ef412cd68e9516a64adb1d1fd2b0/tmp/artifacts/.whl/ray-3.0.0.dev0-cp38-cp38-manylinux2014_x86_64.whl
! pip install ray[tune]
! pip install torch
! pip install torchvision
! pip install tqdm
! pip install anyscale
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#   Using cached https://ray-ci-artifact-pr-public.s3.amazonaws.com/7d65ae53c243ef412cd68e9516a64adb1d1fd2b0/tmp/artifacts/.whl/ray-3.0.0.dev0-cp38-cp38-manylinux2014_x86_64.whl (59.2 MB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# ...

# %%
! aws s3 cp s3://air-example-data-2/movie-image-small-filesize-1GB /home/ec2-user/SageMaker/movie-posters --recursive
